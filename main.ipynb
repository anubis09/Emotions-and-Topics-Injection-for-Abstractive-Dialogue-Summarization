# %% [markdown]
# # Setting up

# %% [markdown]
#  Python version update

# %%
# !python3 --version
# Out:
# Python 3.10.12

# %%
# %%capture
# !sudo apt-get install python3.8
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
# !sudo update-alternatives --config python3

# %%
# !python3 --version
# Out:
# Python 3.8.18

# %%
# %%capture
# !sudo apt install python3-pip
# !sudo apt install python3.8-distutils

# %%
# !apt-get install python3-tk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-tk is already the newest version (3.10.8-1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %% [markdown]
# Cloning project repo

# %%
# REMEMBER TO LOAD THE COMET_Data AND new_datasets_samsum_json FOLDERS INTO THE BELOW PATH!!
dest_folder_comet_Data = "/src/data/COMET_Data"
dest_folder_new_datasets_samsum_json = (
    "/src/data/COMET_Data/paracomet/dialogue/samsum/"
)
# Out:
# '/content/SICK_Summarization/src/data/COMET_Data/paracomet/dialogue/samsum/'

# %% [markdown]
# Installing all the requirements

# %%
# %%capture
# !pip install torch -f https://download.pytorch.org/whl/cu113/torch_stable.html
# !pip install -r requirements.txt
# !pip install -U spacy
# !python -m spacy download en_core_web_sm

# %% [markdown]
# # Training

# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# *Please select and run one of the following three cells based on the extension you want to train.*

# %%
# RUN THIS CELL IF YOU WANT TO TRAIN THE MODEL WITHOUT OUR EXTENSIONS.

# !python3 src/train_summarization_context.py --finetune_weight_path="./new_weights_sick" --best_finetune_weight_path="./new_weights_sick_best" --dataset_name="samsum" --use_paracomet=True --model_name="facebook/bart-large-xsum" --relation "xIntent" --epoch=1 --use_sentence_transformer=True

# %%
# RUN THIS CELL IF YOU WANT TO TRAIN THE MODEL WITH EMOTION INJECTION.

# !python3 src/train_summarization_context.py --finetune_weight_path="./new_weights_sick" --best_finetune_weight_path="./new_weights_sick_best" --dataset_name="samsum" --use_paracomet=True --model_name="facebook/bart-large-xsum" --relation "xIntent" --epoch=1 --use_sentence_transformer=True --is_emotion_injection=True

# %%
# RUN THIS CELL IF YOU WANT TO TRAIN THE MODEL WITH TOPIC INJECTION.

# !python3 src/train_summarization_context.py --finetune_weight_path="./new_weights_sick" --best_finetune_weight_path="./new_weights_sick_best" --dataset_name="samsum" --use_paracomet=True --model_name="facebook/bart-large-xsum" --relation "xIntent" --epoch=1 --use_sentence_transformer=True --is_topic_injection=False

# %% [markdown]
# # Inference

# %% [markdown]
# *Please select and run one of the following three cells based on the extension you want to infer.*

# %%
# Please insert below the correct model weight path!
model_weigth_path = ""

# %%
# !python3 src/inference.py --dataset_name "samsum" --model_checkpoint={model_weigth_path} --test_output_file_name="./tmp_result.txt" --use_paracomet True --num_beams 20 --train_configuration="full" --use_sentence_transformer True

# %% [markdown]
# Results for the model without extensions:
#
#
#
# bert-score 0.6794667606752579
#
#
# {'rouge1': 47.21270498563441, 'rouge2': 21.84850931648293, 'rougeL': 38.03338070316514, 'rougeLsum': 43.053891897822076}

# %%
# !python3 src/inference.py --dataset_name "samsum" --model_checkpoint={model_weigth_path} --test_output_file_name="./tmp_result.txt" --use_paracomet True --num_beams 20 --train_configuration="full" --use_sentence_transformer True --is_emotion_injection=True

# %% [markdown]
# Results for the model with emotion injection:
#
#
# bert-score 0.6823662225070599
#
#
# {'rouge1': 47.42621896327146, 'rouge2': 22.39296754543764, 'rougeL': 38.36632900293439, 'rougeLsum': 43.11209298258561}

# %%
# !python3 src/inference.py --dataset_name "samsum" --model_checkpoint={model_weigth_path} --test_output_file_name="./tmp_result.txt" --use_paracomet True --num_beams 20 --train_configuration="full" --use_sentence_transformer True --is_topic_injection=True

# %% [markdown]
# Results for the model with topic injection:
#
#
# bert-score
# 0.6860536978794978
#
#
# {'rouge1': 48.02217681030005, 'rouge2': 22.907343790313963, 'rougeL': 38.93748073243402, 'rougeLsum': 43.69693699377467}
